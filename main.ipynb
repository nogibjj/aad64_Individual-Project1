# %%
from lib import average, med, standard_deviation, visualize_data

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

testing_data = pd.read_csv("RiskData_SumScores.csv")

# %%
def testing_main_avg():
    assert average(testing_data.loc[:, "Happy"]) == 75.29


def testing_main_med():
    assert med(testing_data.loc[:, "Happy"]) == 78.5


def testing_main_std():
    assert standard_deviation(testing_data.loc[:, "Happy"]) == 14.41

# %% [markdown]
# ### Note
#
# The above code has been taken from test_lib.py, which tests the average, median, and standard deviation functions that were written in lib.py. While main.py uses these functions to retrieve the descriptive statistics of socioeconomic status scores of the Risk Data dataset to tell a story that will lead to the violinplots, this test file is testing another column (Happiness Scores) to ensure that it is globally working.

# %%
visualize_data(
    testing_data,
    "SES",
    "RiskPreferences",
    hue="Gender",
    title="Violin Plot for Age vs Risk Preferences, separated by Gender [1: Male; 2: Female]",
    xlabel="Socioeconomic Status",
    ylabel="Risk Preferences",
)
# Out:
# /Users/aaryadesai/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/aaryadesai/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/aaryadesai/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
from main import summary_stats

df = pd.read_csv("RiskData_SumScores.csv")


print(
    "Overall summary statistics of full dataset relating to Risk Data is: "
    + "\n"
    + str(summary_stats(df))
)
# Out:
# Overall summary statistics of full dataset relating to Risk Data is:
#                Subj      Gender         Age         SES    Siblings  \
# count  1.500000e+02  150.000000  150.000000  150.000000  150.000000
# mean   6.636326e+07    1.366667   24.180000    4.573333    1.600000
# std    1.934511e+06    0.483509    3.361986    1.731457    1.068148
# min    6.400640e+07    1.000000   20.000000    1.000000    0.000000
# 25%    6.416175e+07    1.000000   22.000000    3.000000    1.000000
# 50%    6.800875e+07    1.000000   23.000000    4.000000    1.000000
# 75%    6.802968e+07    2.000000   26.000000    5.750000    2.000000
# max    6.805090e+07    2.000000   36.000000   10.000000    5.000000
#
#          Numeracy        SOEP   SOEPdrive  SOEPfinance  SOEPhealth  ...  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000  ...
# mean     1.733333    6.080000    4.046667     3.740000    5.333333  ...
# ...

# %%
print("Mean SES score of the sample is: " + str(average(df.loc[:, "SES"])))

print("Median SES score of the given sample is: " + str(med(df.loc[:, "SES"])))

print(
    "Standard Deviation of the SES score is: "
    + str(standard_deviation(df.loc[:, "SES"]))
)
# Out:
# Mean SES score of the sample is: 4.57
# Median SES score of the given sample is: 4.0
# Standard Deviation of the SES score is: 1.73
